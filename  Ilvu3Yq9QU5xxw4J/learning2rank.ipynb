# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import MinMaxScaler
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import ndcg_score

# %%
# Define a function to compute cosine similarity between two texts
def sim_vec(model_path, query, docs):
    model = SentenceTransformer(model_path)
    q = model.encode([query], normalize_embeddings=True)
    d = model.encode(docs, normalize_embeddings=True)
    sims = model.similarity(q, d)
    return sims[0]

# %% [markdown]
# ## Data Prep

# %%
# Load data
df = pd.read_csv("potential-talents - Aspiring human resources - seeking human resources.csv")
# Clean and convert 'connection' column
df["connection"] = df["connection"].astype(str).str.replace("+", "", regex=False).astype(int)
df.connection.min()
scaler = MinMaxScaler()
df["connection"] = scaler.fit_transform(df[["connection"]])
df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location  connection  fit
# 0                         Houston, Texas    0.168337  NaN
# 1                                 Kanada    1.000000  NaN
# 2    Raleigh-Durham, North Carolina Area    0.086172  NaN
# 3                          Denton, Texas    1.000000  NaN
# 4                         İzmir, Türkiye    1.000000  NaN
# ..                                   ...         ...  ...
# 99              Cape Girardeau, Missouri    0.204409  NaN
# 100  Raleigh-Durham, North Carolina Area    1.000000  NaN
# 101           Greater New York City Area    0.096192  NaN
# 102             Greater Los Angeles Area    1.000000  NaN
# 103                          Katy, Texas    1.000000  NaN
#
# [104 rows x 5 columns]

# %%
# Remove duplicate entries based on job_title, location, and connection
df_nodup = df.copy().drop_duplicates(subset=["job_title", "location", "connection"],keep='first')
df_nodup.drop(columns= ["location","fit"], inplace=True)
df_nodup.reset_index(drop=True, inplace=True)
doc = df_nodup['job_title'].tolist()
query = "Aspiring human resources"

df_nodup.shape #cuts by half
# Out:
# (53, 3)

# %%
# Similarirty scores
df_nodup["mnet_sim"] = sim_vec("sentence-transformers/all-mpnet-base-v2",query,doc)
df_nodup["mLM_sim"] = sim_vec("all-MiniLM-L6-v2",query,doc)

# %%
df_nodup["quen_sim"] = sim_vec("Qwen/Qwen3-Embedding-0.6B", query,doc) 
df_clean = df_nodup.copy()

# %%
df_clean["mnet_score"] = (df_clean["mnet_sim"] *0.90) + (df_clean["connection"] *0.1)
df_clean["mLM_score"] = (df_clean["mLM_sim"] *0.90) + (df_clean["connection"] *0.1)
df_clean["quen_score"] = (df_clean["quen_sim"] *0.90) + (df_clean["connection"] *0.1)

# %%
df_clean["rank"] = (
    ((df_clean["mnet_score"] >= df_clean["mnet_score"].quantile(0.75)).astype(int) +
     (df_clean["mLM_score"] >= df_clean["mLM_score"].quantile(0.75)).astype(int) +
     (df_clean["quen_score"] >= df_clean["quen_score"].quantile(0.75)).astype(int))
    .apply(lambda x: 1 if x >= 1 else 0)
)

# %%
df_clean[df_clean["rank"] == 1]
# Out:
#      id                                          job_title  connection  \
# 0     1  2019 C.T. Bauer College of Business Graduate (...    0.168337
# 2     3              Aspiring Human Resources Professional    0.086172
# 5     6                Aspiring Human Resources Specialist    0.000000
# 6     7  Student at Humber College and Aspiring Human R...    0.120240
# 8    10  Seeking Human Resources HRIS and Generalist Po...    1.000000
# 12   27  Aspiring Human Resources Management student se...    1.000000
# 13   28              Seeking Human Resources Opportunities    0.779559
# 14   66  Experienced Retail Manager and aspiring Human ...    0.112224
# 15   67  Human Resources, Staffing and Recruiting Profe...    1.000000
# 16   68            Human Resources Specialist at Luxottica    1.000000
# 21   73  Aspiring Human Resources Manager, seeking inte...    0.012024
# 22   74                       Human Resources Professional    0.030060
# 24   76  Aspiring Human Resources Professional | Passio...    0.422846
# 26   78             Human Resources Generalist at Schwan's    1.000000
# 30   82  Aspiring Human Resources Professional | An ene...    0.346693
# 36   88                   Human Resources Management Major    0.034068
# 45   97              Aspiring Human Resources Professional    0.140281
# 47   99                   Seeking Human Resources Position    0.094188
# 48  100  Aspiring Human Resources Manager | Graduating ...    0.204409
# 49  101              Human Resources Generalist at Loparex    1.000000
#
#     mnet_sim   mLM_sim  quen_sim  mnet_score  mLM_score  quen_score  rank
# 0   0.721934  0.573268  0.635231    0.666574   0.532775    0.588542     1
# 2   0.879234  0.949807  0.959759    0.799928   0.863444    0.872401     1
# 5   0.864964  0.928035  0.945432    0.778467   0.835231    0.850889     1
# 6   0.728648  0.757811  0.781263    0.667808   0.694054    0.715161     1
# 8   0.591348  0.744711  0.830001    0.632214   0.770240    0.847001     1
# 12  0.631580  0.720099  0.844989    0.668422   0.748089    0.860490     1
# 13  0.696302  0.799642  0.854704    0.704628   0.797633    0.847189     1
# 14  0.652588  0.696065  0.842892    0.598551   0.637681    0.769826     1
# 15  0.697636  0.745484  0.801545    0.727872   0.770935    0.821391     1
# 16  0.565116  0.622302  0.712178    0.608604   0.660072    0.740960     1
# 21  0.690075  0.717391  0.864440    0.622270   0.646854    0.779199     1
# 22  0.754995  0.794648  0.809908    0.682502   0.718189    0.731923     1
# 24  0.699148  0.749486  0.800923    0.671518   0.716822    0.763115     1
# 26  0.589669  0.623912  0.696117    0.630702   0.661521    0.726505     1
# 30  0.775665  0.784048  0.804608    0.732768   0.740313    0.758816     1
# 36  0.699121  0.726044  0.757542    0.632616   0.656847    0.685195     1
# 45  0.879234  0.949807  0.959759    0.805338   0.868855    0.877811     1
# 47  0.619792  0.808784  0.854263    0.567231   0.737325    0.778255     1
# 48  0.654831  0.760215  0.745673    0.609789   0.704634    0.691547     1
# 49  0.575439  0.603002  0.711140    0.617895   0.642702    0.740026     1

# %%
X = df_clean[["mnet_score","mLM_score","quen_score"]]
y = df_clean["rank"]

# %% [markdown]
# ## Modeling

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
query_train = [X_train.shape[0]]
query_test = [X_test.shape[0]]

# %%
train_data = lgb.Dataset(X_train, label=y_train, group=query_train)
test_data = lgb.Dataset(X_test, label=y_test, group=query_test)

# %%
params = {
   'objective': 'lambdarank',
   'metric': 'ndcg',
   'learning_rate': 0.1,
   'num_leaves': 31,
   'min_data_in_leaf': 1,
   'verbose': -1
}

# %%
gbm = lgb.train(
   params,
   train_data,
   valid_sets=[test_data],
   num_boost_round=100,
   callbacks=[lgb.early_stopping(stopping_rounds=10)]
)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	valid_0's ndcg@1: 1	valid_0's ndcg@2: 1	valid_0's ndcg@3: 1	valid_0's ndcg@4: 1	valid_0's ndcg@5: 1

# %%
y_pred = gbm.predict(X_test)
score = ndcg_score([y_test], [y_pred])
print(f"NDCG Score: {score}")
# Out:
# NDCG Score: 1.0
