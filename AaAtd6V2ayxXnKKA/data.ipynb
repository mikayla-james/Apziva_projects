# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.investing.com/crypto/bitcoin/historical-data/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
 <div class="mt-6 flex flex-col items-start overflow-x-auto p-0 md:pl-1"><table class="freeze-column-w-1 w-full overflow-x-auto text-xs leading-4"><thead class="relative after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF]"><tr class="h-[41px]"><th class="datatable-v2_cell__IwP1U sticky left-0 min-w-[106px] bg-white text-left font-semibold text-v2-black"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>Date</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th><th class="datatable-v2_cell__IwP1U text-v2-black font-semibold text-xs leading-4 tracking-[0.2px] text-right rtl:text-right w-[10%] min-w-[77px]"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>Price</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th><th class="datatable-v2_cell__IwP1U text-v2-black font-semibold text-xs leading-4 tracking-[0.2px] text-right rtl:text-right w-[10%] min-w-[77px]"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>Open</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th><th class="datatable-v2_cell__IwP1U text-v2-black font-semibold text-xs leading-4 tracking-[0.2px] text-right rtl:text-right w-[10%] min-w-[77px]"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>High</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th><th class="datatable-v2_cell__IwP1U text-v2-black font-semibold text-xs leading-4 tracking-[0.2px] text-right rtl:text-right w-[10%] min-w-[77px]"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>Low</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th><th class="datatable-v2_cell__IwP1U text-v2-black font-semibold text-xs leading-4 tracking-[0.2px] text-right rtl:text-right w-[10%] min-w-[87px]"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>Vol.</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th><th class="datatable-v2_cell__IwP1U text-v2-black font-semibold text-xs leading-4 tracking-[0.2px] text-right rtl:text-right w-[10%] min-w-[82px]"><div class="datatable-v2_cell__wrapper__7O0wk !block md:!inline-flex"><button class="relative inline-flex items-center justify-center whitespace-nowrap rounded-sm p-1.5 text-xs font-bold leading-tight no-underline disabled:bg-inv-grey-50 disabled:text-inv-grey-400 text-inv-grey-700 datatable-v2_sort__oHEK5 !font-semibold !leading-4 text-primary" type="button"><span>Change %</span><span class="flex"><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM datatable-v2_sort-icon-up__hKaZQ !hidden" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg><svg viewBox="0 0 14 14" width="14" fill="none" class="datatable-v2_sort-icon__lTndM opacity-40" aria-hidden="true" height="14" style="height: auto;"><path fill="currentColor" d="M10.627 4.66675C11.0463 4.66675 11.2793 5.15171 11.0174 5.4791L7.39109 10.012C7.19092 10.2622 6.81038 10.2622 6.61022 10.012L2.98386 5.4791C2.72196 5.15171 2.95504 4.66675 3.3743 4.66675H10.627Z"></path></svg></span></button></div></th></tr></thead><tbody><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 11, 2025">Dec 11, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">90,292.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,005.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,079.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,459.6</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">65.09K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.85%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 10, 2025">Dec 10, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">91,996.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,685.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,458.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,608.0</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">61.84K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-0.75%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 09, 2025">Dec 09, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">92,693.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,636.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,591.4</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,592.2</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">68.38K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+2.27%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 08, 2025">Dec 08, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">90,636.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,413.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,269.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,640.7</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">51.82K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+0.25%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 07, 2025">Dec 07, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">90,413.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,209.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,736.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">87,747.6</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">38.67K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+1.35%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 06, 2025">Dec 06, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">89,209.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,333.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,176.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">88,929.5</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">30.14K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-0.14%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 05, 2025">Dec 05, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">89,333.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,082.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,676.4</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">88,218.4</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">61.14K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-2.99%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 04, 2025">Dec 04, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">92,082.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">93,437.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,043.9</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,933.2</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">60.28K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.45%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 03, 2025">Dec 03, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">93,437.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,286.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,077.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,020.8</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">79.02K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+2.35%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 02, 2025">Dec 02, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">91,287.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,315.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,285.4</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,189.8</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">87.36K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+5.77%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Dec 01, 2025">Dec 01, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">86,309.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,372.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,372.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">83,858.1</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">105.96K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-4.50%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 30, 2025">Nov 30, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">90,374.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,804.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,957.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,351.7</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">31.09K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-0.47%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 29, 2025">Nov 29, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">90,800.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,894.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,160.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,225.3</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">28.05K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-0.10%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 28, 2025">Nov 28, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">90,894.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,324.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,942.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,221.5</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">60.08K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-0.47%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 27, 2025">Nov 27, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">91,324.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,497.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,888.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,099.9</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">58.08K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+0.92%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 26, 2025">Nov 26, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">90,496.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">87,363.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">90,582.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,334.8</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">70.68K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+3.58%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 25, 2025">Nov 25, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">87,366.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">88,296.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">88,502.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,162.0</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">70.67K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.05%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 24, 2025">Nov 24, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">88,296.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,828.4</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,210.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">85,307.2</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">81.64K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+1.69%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 23, 2025">Nov 23, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">86,826.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">84,729.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">87,995.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">84,729.0</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">67.53K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+2.48%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 22, 2025">Nov 22, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">84,721.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">85,117.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">85,557.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">83,518.8</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">49.35K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-0.48%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 21, 2025">Nov 21, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">85,131.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,610.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">87,460.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">80,697.7</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">177.95K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.71%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 20, 2025">Nov 20, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">86,613.9</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,543.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">93,123.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">86,105.4</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">114.40K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-5.39%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 19, 2025">Nov 19, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">91,544.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,962.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,962.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">88,610.4</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">95.86K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.53%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 18, 2025">Nov 18, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">92,962.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">92,196.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">93,781.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">89,391.9</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">115.10K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+0.83%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 17, 2025">Nov 17, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">92,195.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,259.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">96,002.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">91,327.8</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">109.89K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-2.19%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 16, 2025">Nov 16, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">94,259.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">95,587.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">96,575.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">93,043.5</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">68.24K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.39%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 15, 2025">Nov 15, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">95,587.6</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,557.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">96,799.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,557.5</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">48.15K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+1.09%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 14, 2025">Nov 14, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">94,554.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">99,707.0</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">99,843.9</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">94,126.2</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">131.30K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-5.19%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 13, 2025">Nov 13, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">99,728.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">101,652.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">104,008.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">98,027.4</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">100.44K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.90%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 12, 2025">Nov 12, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">101,658.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">103,046.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">105,309.1</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">100,858.0</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">63.52K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-1.35%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 11, 2025">Nov 11, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-negative-main" dir="ltr">103,046.7</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">106,003.2</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">107,461.3</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">102,484.3</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">73.04K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--down___c4Fq min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-negative-main" dir="ltr">-2.79%</td></tr><tr class="relative h-[41px] after:absolute after:bottom-0 after:left-0 after:right-0 after:h-px after:bg-[#ECEDEF] hover:bg-secondary historical-data-v2_price__atUfP"><td class="datatable_cell__LJp3C sticky left-0 min-w-[106px] overflow-hidden text-ellipsis whitespace-nowrap bg-white text-left align-middle text-sm font-semibold leading-4 text-v2-black sm:bg-inherit"><time datetime="Nov 10, 2025">Nov 10, 2025</time></td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[77px] text-right align-middle text-sm font-normal leading-5 rtl:text-right text-positive-main" dir="ltr">106,006.9</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">104,720.8</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">106,629.5</td><td class="min-w-[77px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-last">104,285.0</td><td class="min-w-[87px] text-right align-middle text-sm font-normal leading-5 text-v2-black rtl:text-right" data-test="relative-most-active-vol">70.75K</td><td class="datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF min-w-[82px] whitespace-nowrap text-right align-middle text-sm font-bold leading-5 rtl:text-right text-positive-main" dir="ltr">+1.23%</td></tr></tbody></table></div>
# Out:
# <!DOCTYPE html>
# ...
